# %% [markdown]
# <a href="https://colab.research.google.com/github/rafaelaabe1/Repositorio-1/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lado1 = 4
lado2 = 3

# Cáuculo da área

area = lado1 * lado2

# Cáuculo da área de um quadrado

areaquadrado = lado1 *lado1

# %%
print(area)
# Out:
# 12

# %%
print(areaquadrado)
# Out:
# 16

# %%
nome = "rafela"
idade = 15
altura = 1.67

# %%
print(nome)
# Out:
# rafela

# %%
nome= "rafaela"

# %%
print(f"nome : {nome}, idade : {idade}, altura : {altura}")
# Out:
# nome : rafela, idade : 15, altura : 1.67
